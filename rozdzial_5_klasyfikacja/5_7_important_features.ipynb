# %%
import pandas as pd

# %%
credit_cards_df = pd.read_parquet("../data/credit-cards-reduced.parquet")
credit_cards_df.T
# Out:
# ID                             1           2            3       4      \
# LIMIT_BAL                      20000      120000        90000   50000
# AGE                               24          26           34      37
# PAY_1                              2          -1            0       0
# PAY_2                              2           2            0       0
# PAY_3                             -1           0            0       0
# PAY_4                             -1           0            0       0
# PAY_5                             -2           0            0       0
# PAY_6                             -2           2            0       0
# BILL_AMT1                       3913        2682        29239   46990
# BILL_AMT2                       3102        1725        14027   48233
# BILL_AMT3                        689        2682        13559   49291
# PAY_AMT1                           0           0         1518    2000
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %%
X = credit_cards_df.drop(columns="DEFAULT")
y = credit_cards_df["DEFAULT"]

# %%
pipeline = Pipeline(steps=[
    ("scaling", MinMaxScaler()),
    ("classification", LogisticRegression(penalty=None, max_iter=10000))
    
])
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('scaling', MinMaxScaler()),
#                 ('classification',
#                  LogisticRegression(max_iter=10000, penalty=None))])

# %%
pd.DataFrame({
    "coef": pipeline.steps[1][1].coef_[0]
}, index=X.columns)
# Out:
#                               coef
# LIMIT_BAL                -1.738269
# AGE                       0.222541
# PAY_1                     2.691888
# PAY_2                    -1.115059
# PAY_3                    -0.633114
# PAY_4                    -1.017960
# PAY_5                    -0.701145
# PAY_6                    -0.613360
# BILL_AMT1                -1.280041
# BILL_AMT2                 2.735309
# BILL_AMT3                 0.639306
# PAY_AMT1                 -6.982373
# PAY_AMT2                 -4.486823
# PAY_AMT4                 -2.383165
# PAY_AMT5                  0.137234
# PAY_OVERDUE_COUNT         3.126534
# WEIGHTED_PAYMENT_HISTORY  0.680847
# AVG_PAY_AMT              -6.001016
# SEX_2                    -0.132359
# EDUCATION_1               0.618977
# EDUCATION_2               0.629389
# EDUCATION_3               0.614506
# EDUCATION_4              -0.530093
# EDUCATION_5              -0.640023
# EDUCATION_6               0.249274
# MARRIAGE_1                2.069828
# ...

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y, pipeline.predict(X)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89     23364
#            1       0.66      0.29      0.40      6636
#
#     accuracy                           0.81     30000
#    macro avg       0.74      0.62      0.64     30000
# weighted avg       0.79      0.81      0.78     30000
