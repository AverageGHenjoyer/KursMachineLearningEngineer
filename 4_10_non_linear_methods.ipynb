# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(2020)
x = np.linspace(0, 10, 12)
xy_df = pd.DataFrame({
    "x": x,
    "y": x ** 2 - 7 * x + 2 * np.random.normal(size=12)
})
xy_df.sample(5)
# Out:
#             x          y
# 0    0.000000  -3.537691
# 3    2.727273 -12.955753
# 10   9.090909  17.405597
# 11  10.000000  32.624070
# 8    7.272727   2.803697

# %%
xy_df.plot.scatter(x="x", y="y", figsize=(10, 7.5))
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Próba rozwiązania metodami liniowymi

# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt

# %%
def draw_line(a, b, x_min=-5, x_max=5, c=(.75, .1, .1, .25)):
    x = np.linspace(x_min, x_max, 1000)
    y = a * x + b
    plt.plot(x, y, "-r", c=c)

# %%
lr = LinearRegression()
lr.fit(xy_df[["x"]], xy_df["y"])
# Out:
# LinearRegression()

# %%
xy_df.plot.scatter(x="x", y="y", figsize=(10, 7.5))
draw_line(lr.coef_[0], lr.intercept_, x_min=0, x_max=10)
# Out:
# /tmp/ipykernel_9739/3270353586.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-r" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x, y, "-r", c=c)

# %% [markdown]
# ### Złożoność modelu

# %%
xy_df.plot.scatter(x="x", y="y", figsize=(10, 7.5))
plt.plot(xy_df["x"], xy_df["y"], "-r")
