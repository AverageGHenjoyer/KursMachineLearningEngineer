# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = np.random.random(size=1000)
xy_df = pd.DataFrame({
    "x": x,
    "y": 2 * x + 0.5 *np.random.normal(size=1000)
})
xy_df.sample(n=5)
# Out:
#             x         y
# 470  0.723077  0.584346
# 338  0.446814  0.391601
# 427  0.146672 -0.268902
# 464  0.489978  1.163020
# 876  0.557324  0.562754

# %%
xy_df.plot.scatter(x="x", y="y", figsize=(10, 7.5))
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(xy_df[["x"]], xy_df["y"])
lr.coef_, lr.intercept_
# Out:
# (array([2.04916926]), np.float64(-0.03224795628302046))

# %%
lr = LinearRegression()
lr.fit(1000 * xy_df[["x"]], xy_df["y"])
lr.coef_, lr.intercept_
# Out:
# (array([0.00204917]), np.float64(-0.032247956283020685))

# %% [markdown]
# ### Skalowanie cech

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm_scaler = MinMaxScaler()
mm_scaler.fit(xy_df[["x"]])
# Out:
# MinMaxScaler()

# %%
xy_df["min_max_scaled_x"] = mm_scaler.transform(xy_df[["x"]]).flatten()
xy_df.plot.scatter(x="min_max_scaled_x", y="y", figsize=(10, 7.5))
# Out:
# <Axes: xlabel='min_max_scaled_x', ylabel='y'>

# %% [markdown]
# ### Standaryzacja

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler = StandardScaler()
std_scaler.fit(xy_df[["x"]])
# Out:
# StandardScaler()

# %%
xy_df["std_scaled_x"] = std_scaler.transform(xy_df[["x"]]).flatten()
xy_df.plot.scatter(x="std_scaled_x", y="y", figsize=(10, 7.5))
# Out:
# <Axes: xlabel='std_scaled_x', ylabel='y'>
